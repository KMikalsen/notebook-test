# %%
print("hello world")
# Out:
# hello world

# %%
import requests

# %%
api_url = "https://test2-api.nifs.no/tournaments/5/stages"

stages = requests.get(url=api_url)

data = stages.json()

es2020id = str(data[0]['id'])

matches_url = "https://test2-api.nifs.no/stages/"+es2020id+"/matches/"
matches = requests.get(url=matches_url)

data2 = matches.json()

data2
# Out:
# [{'timestamp': '2020-06-16T18:00:00+02:00',
#   'name': 'Aalesund - Molde',
#   'result': {'homeScore45': 1,
#    'homeScore90': 1,
#    'awayScore45': 2,
#    'awayScore90': 4,
#    'type': 'nifs:result',
#    'uid': 'res_1800721'},
#   'homeTeam': {'logo': {'url': 'https://s3-eu-west-1.amazonaws.com/ntb-nifs/43621.png',
#     'type': 'nifs:image',
#     'uid': 'i_43621',
#     'id': 43621},
#    'matchStatistics': None,
#    'name': 'Aalesund',
#    'names': None,
#    'clubs': [{'name': 'Aalesunds Fotballklubb',
#      'primaryColor': '#FE8651',
#      'secondaryColor': '#007BBD',
#      'textColor': '#000000',
#      'type': 'nifs:clubCompact',
#      'uid': 'cl_c_3180',
#      'id': 3180,
#      'sportId': 1}],
#    'shortName': 'AaFK',
#    'type': 'nifs:team',
#    'uid': 'tim_46_1800721',
#    'id': 46,
#    'externalIds': {'tv2': [281], 'fiks': [15]}},
#   'awayTeam': {'logo': {'url': 'https://s3-eu-west-1.amazonaws.com/ntb-nifs/16670.png',
#     'type': 'nifs:image',
# ...
